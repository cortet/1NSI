# %% [markdown]
# #Le codage binaire

# %% [markdown]
# ##Rappel : Bibliothèque de référence Python
# https://docs.python.org/fr/3/reference/index.html#reference-index

# %% [markdown]
# ##Objectif du programme :
# ##Etape 1 :
# Ecrire une boucle de 0 à 300 qui écrit la conversion en binaire d'un nombre.
# On obtient en sortie :
#
# 0 sécrit en binaire  0
# 1 sécrit en binaire  1
# 2 sécrit en binaire  10
# 3 sécrit en binaire  11.....

# %%
#Etape 1 et 2:
for a in range(0 ,300 ):
    #convertir a en binaire et l'affecter à une nouvelle variable
    abin = bin(a)
    #Ecrire la phrase de synthese
    print (a, "s'écrit en binaire : ", abin[2:], "sur ", len(abin[2:]) , " bits")
# Out:
# 0 s'écrit en binaire :  0 sur  1  bits
# 1 s'écrit en binaire :  1 sur  1  bits
# 2 s'écrit en binaire :  10 sur  2  bits
# 3 s'écrit en binaire :  11 sur  2  bits
# 4 s'écrit en binaire :  100 sur  3  bits
# 5 s'écrit en binaire :  101 sur  3  bits
# 6 s'écrit en binaire :  110 sur  3  bits
# 7 s'écrit en binaire :  111 sur  3  bits
# 8 s'écrit en binaire :  1000 sur  4  bits
# 9 s'écrit en binaire :  1001 sur  4  bits
# 10 s'écrit en binaire :  1010 sur  4  bits
# 11 s'écrit en binaire :  1011 sur  4  bits
# 12 s'écrit en binaire :  1100 sur  4  bits
# 13 s'écrit en binaire :  1101 sur  4  bits
# 14 s'écrit en binaire :  1110 sur  4  bits
# 15 s'écrit en binaire :  1111 sur  4  bits
# 16 s'écrit en binaire :  10000 sur  5  bits
# 17 s'écrit en binaire :  10001 sur  5  bits
# 18 s'écrit en binaire :  10010 sur  5  bits
# 19 s'écrit en binaire :  10011 sur  5  bits
# 20 s'écrit en binaire :  10100 sur  5  bits
# 21 s'écrit en binaire :  10101 sur  5  bits
# 22 s'écrit en binaire :  10110 sur  5  bits
# 23 s'écrit en binaire :  10111 sur  5  bits
# 24 s'écrit en binaire :  11000 sur  5  bits
# 25 s'écrit en binaire :  11001 sur  5  bits
# 26 s'écrit en binaire :  11010 sur  5  bits
# 27 s'écrit en binaire :  11011 sur  5  bits
# 28 s'écrit en binaire :  11100 sur  5  bits
# 29 s'écrit en binaire :  11101 sur  5  bits
# 30 s'écrit en binaire :  11110 sur  5  bits
# 31 s'écrit en binaire :  11111 sur  5  bits
# 32 s'écrit en binaire :  100000 sur  6  bits
# 33 s'écrit en binaire :  100001 sur  6  bits
# 34 s'écrit en binaire :  100010 sur  6  bits
# 35 s'écrit en binaire :  100011 sur  6  bits
# 36 s'écrit en binaire :  100100 sur  6  bits
# 37 s'écrit en binaire :  100101 sur  6  bits
# 38 s'écrit en binaire :  100110 sur  6  bits
# 39 s'écrit en binaire :  100111 sur  6  bits
# 40 s'écrit en binaire :  101000 sur  6  bits
# 41 s'écrit en binaire :  101001 sur  6  bits
# 42 s'écrit en binaire :  101010 sur  6  bits
# 43 s'écrit en binaire :  101011 sur  6  bits
# 44 s'écrit en binaire :  101100 sur  6  bits
# 45 s'écrit en binaire :  101101 sur  6  bits
# 46 s'écrit en binaire :  101110 sur  6  bits
# 47 s'écrit en binaire :  101111 sur  6  bits
# 48 s'écrit en binaire :  110000 sur  6  bits
# 49 s'écrit en binaire :  110001 sur  6  bits
# 50 s'écrit en binaire :  110010 sur  6  bits
# 51 s'écrit en binaire :  110011 sur  6  bits
# 52 s'écrit en binaire :  110100 sur  6  bits
# 53 s'écrit en binaire :  110101 sur  6  bits
# 54 s'écrit en binaire :  110110 sur  6  bits
# 55 s'écrit en binaire :  110111 sur  6  bits
# 56 s'écrit en binaire :  111000 sur  6  bits
# 57 s'écrit en binaire :  111001 sur  6  bits
# 58 s'écrit en binaire :  111010 sur  6  bits
# 59 s'écrit en binaire :  111011 sur  6  bits
# 60 s'écrit en binaire :  111100 sur  6  bits
# 61 s'écrit en binaire :  111101 sur  6  bits
# 62 s'écrit en binaire :  111110 sur  6  bits
# 63 s'écrit en binaire :  111111 sur  6  bits
# 64 s'écrit en binaire :  1000000 sur  7  bits
# 65 s'écrit en binaire :  1000001 sur  7  bits
# 66 s'écrit en binaire :  1000010 sur  7  bits
# 67 s'écrit en binaire :  1000011 sur  7  bits
# 68 s'écrit en binaire :  1000100 sur  7  bits
# 69 s'écrit en binaire :  1000101 sur  7  bits
# 70 s'écrit en binaire :  1000110 sur  7  bits
# 71 s'écrit en binaire :  1000111 sur  7  bits
# 72 s'écrit en binaire :  1001000 sur  7  bits
# 73 s'écrit en binaire :  1001001 sur  7  bits
# 74 s'écrit en binaire :  1001010 sur  7  bits
# 75 s'écrit en binaire :  1001011 sur  7  bits
# 76 s'écrit en binaire :  1001100 sur  7  bits
# 77 s'écrit en binaire :  1001101 sur  7  bits
# 78 s'écrit en binaire :  1001110 sur  7  bits
# 79 s'écrit en binaire :  1001111 sur  7  bits
# 80 s'écrit en binaire :  1010000 sur  7  bits
# 81 s'écrit en binaire :  1010001 sur  7  bits
# 82 s'écrit en binaire :  1010010 sur  7  bits
# 83 s'écrit en binaire :  1010011 sur  7  bits
# 84 s'écrit en binaire :  1010100 sur  7  bits
# 85 s'écrit en binaire :  1010101 sur  7  bits
# 86 s'écrit en binaire :  1010110 sur  7  bits
# 87 s'écrit en binaire :  1010111 sur  7  bits
# 88 s'écrit en binaire :  1011000 sur  7  bits
# 89 s'écrit en binaire :  1011001 sur  7  bits
# 90 s'écrit en binaire :  1011010 sur  7  bits
# 91 s'écrit en binaire :  1011011 sur  7  bits
# 92 s'écrit en binaire :  1011100 sur  7  bits
# 93 s'écrit en binaire :  1011101 sur  7  bits
# 94 s'écrit en binaire :  1011110 sur  7  bits
# 95 s'écrit en binaire :  1011111 sur  7  bits
# 96 s'écrit en binaire :  1100000 sur  7  bits
# 97 s'écrit en binaire :  1100001 sur  7  bits
# 98 s'écrit en binaire :  1100010 sur  7  bits
# 99 s'écrit en binaire :  1100011 sur  7  bits
# 100 s'écrit en binaire :  1100100 sur  7  bits
# 101 s'écrit en binaire :  1100101 sur  7  bits
# 102 s'écrit en binaire :  1100110 sur  7  bits
# 103 s'écrit en binaire :  1100111 sur  7  bits
# 104 s'écrit en binaire :  1101000 sur  7  bits
# 105 s'écrit en binaire :  1101001 sur  7  bits
# 106 s'écrit en binaire :  1101010 sur  7  bits
# 107 s'écrit en binaire :  1101011 sur  7  bits
# 108 s'écrit en binaire :  1101100 sur  7  bits
# 109 s'écrit en binaire :  1101101 sur  7  bits
# 110 s'écrit en binaire :  1101110 sur  7  bits
# 111 s'écrit en binaire :  1101111 sur  7  bits
# 112 s'écrit en binaire :  1110000 sur  7  bits
# 113 s'écrit en binaire :  1110001 sur  7  bits
# 114 s'écrit en binaire :  1110010 sur  7  bits
# 115 s'écrit en binaire :  1110011 sur  7  bits
# 116 s'écrit en binaire :  1110100 sur  7  bits
# 117 s'écrit en binaire :  1110101 sur  7  bits
# 118 s'écrit en binaire :  1110110 sur  7  bits
# 119 s'écrit en binaire :  1110111 sur  7  bits
# 120 s'écrit en binaire :  1111000 sur  7  bits
# 121 s'écrit en binaire :  1111001 sur  7  bits
# 122 s'écrit en binaire :  1111010 sur  7  bits
# 123 s'écrit en binaire :  1111011 sur  7  bits
# 124 s'écrit en binaire :  1111100 sur  7  bits
# 125 s'écrit en binaire :  1111101 sur  7  bits
# 126 s'écrit en binaire :  1111110 sur  7  bits
# 127 s'écrit en binaire :  1111111 sur  7  bits
# 128 s'écrit en binaire :  10000000 sur  8  bits
# 129 s'écrit en binaire :  10000001 sur  8  bits
# 130 s'écrit en binaire :  10000010 sur  8  bits
# 131 s'écrit en binaire :  10000011 sur  8  bits
# 132 s'écrit en binaire :  10000100 sur  8  bits
# 133 s'écrit en binaire :  10000101 sur  8  bits
# 134 s'écrit en binaire :  10000110 sur  8  bits
# 135 s'écrit en binaire :  10000111 sur  8  bits
# 136 s'écrit en binaire :  10001000 sur  8  bits
# 137 s'écrit en binaire :  10001001 sur  8  bits
# 138 s'écrit en binaire :  10001010 sur  8  bits
# 139 s'écrit en binaire :  10001011 sur  8  bits
# 140 s'écrit en binaire :  10001100 sur  8  bits
# 141 s'écrit en binaire :  10001101 sur  8  bits
# 142 s'écrit en binaire :  10001110 sur  8  bits
# 143 s'écrit en binaire :  10001111 sur  8  bits
# 144 s'écrit en binaire :  10010000 sur  8  bits
# 145 s'écrit en binaire :  10010001 sur  8  bits
# 146 s'écrit en binaire :  10010010 sur  8  bits
# 147 s'écrit en binaire :  10010011 sur  8  bits
# 148 s'écrit en binaire :  10010100 sur  8  bits
# 149 s'écrit en binaire :  10010101 sur  8  bits
# 150 s'écrit en binaire :  10010110 sur  8  bits
# 151 s'écrit en binaire :  10010111 sur  8  bits
# 152 s'écrit en binaire :  10011000 sur  8  bits
# 153 s'écrit en binaire :  10011001 sur  8  bits
# 154 s'écrit en binaire :  10011010 sur  8  bits
# 155 s'écrit en binaire :  10011011 sur  8  bits
# 156 s'écrit en binaire :  10011100 sur  8  bits
# 157 s'écrit en binaire :  10011101 sur  8  bits
# 158 s'écrit en binaire :  10011110 sur  8  bits
# 159 s'écrit en binaire :  10011111 sur  8  bits
# 160 s'écrit en binaire :  10100000 sur  8  bits
# 161 s'écrit en binaire :  10100001 sur  8  bits
# 162 s'écrit en binaire :  10100010 sur  8  bits
# 163 s'écrit en binaire :  10100011 sur  8  bits
# 164 s'écrit en binaire :  10100100 sur  8  bits
# 165 s'écrit en binaire :  10100101 sur  8  bits
# 166 s'écrit en binaire :  10100110 sur  8  bits
# 167 s'écrit en binaire :  10100111 sur  8  bits
# 168 s'écrit en binaire :  10101000 sur  8  bits
# 169 s'écrit en binaire :  10101001 sur  8  bits
# 170 s'écrit en binaire :  10101010 sur  8  bits
# 171 s'écrit en binaire :  10101011 sur  8  bits
# 172 s'écrit en binaire :  10101100 sur  8  bits
# 173 s'écrit en binaire :  10101101 sur  8  bits
# 174 s'écrit en binaire :  10101110 sur  8  bits
# 175 s'écrit en binaire :  10101111 sur  8  bits
# 176 s'écrit en binaire :  10110000 sur  8  bits
# 177 s'écrit en binaire :  10110001 sur  8  bits
# 178 s'écrit en binaire :  10110010 sur  8  bits
# 179 s'écrit en binaire :  10110011 sur  8  bits
# 180 s'écrit en binaire :  10110100 sur  8  bits
# 181 s'écrit en binaire :  10110101 sur  8  bits
# 182 s'écrit en binaire :  10110110 sur  8  bits
# 183 s'écrit en binaire :  10110111 sur  8  bits
# 184 s'écrit en binaire :  10111000 sur  8  bits
# 185 s'écrit en binaire :  10111001 sur  8  bits
# 186 s'écrit en binaire :  10111010 sur  8  bits
# 187 s'écrit en binaire :  10111011 sur  8  bits
# 188 s'écrit en binaire :  10111100 sur  8  bits
# 189 s'écrit en binaire :  10111101 sur  8  bits
# 190 s'écrit en binaire :  10111110 sur  8  bits
# 191 s'écrit en binaire :  10111111 sur  8  bits
# 192 s'écrit en binaire :  11000000 sur  8  bits
# 193 s'écrit en binaire :  11000001 sur  8  bits
# 194 s'écrit en binaire :  11000010 sur  8  bits
# 195 s'écrit en binaire :  11000011 sur  8  bits
# 196 s'écrit en binaire :  11000100 sur  8  bits
# 197 s'écrit en binaire :  11000101 sur  8  bits
# 198 s'écrit en binaire :  11000110 sur  8  bits
# 199 s'écrit en binaire :  11000111 sur  8  bits
# 200 s'écrit en binaire :  11001000 sur  8  bits
# 201 s'écrit en binaire :  11001001 sur  8  bits
# 202 s'écrit en binaire :  11001010 sur  8  bits
# 203 s'écrit en binaire :  11001011 sur  8  bits
# 204 s'écrit en binaire :  11001100 sur  8  bits
# 205 s'écrit en binaire :  11001101 sur  8  bits
# 206 s'écrit en binaire :  11001110 sur  8  bits
# 207 s'écrit en binaire :  11001111 sur  8  bits
# 208 s'écrit en binaire :  11010000 sur  8  bits
# 209 s'écrit en binaire :  11010001 sur  8  bits
# 210 s'écrit en binaire :  11010010 sur  8  bits
# 211 s'écrit en binaire :  11010011 sur  8  bits
# 212 s'écrit en binaire :  11010100 sur  8  bits
# 213 s'écrit en binaire :  11010101 sur  8  bits
# 214 s'écrit en binaire :  11010110 sur  8  bits
# 215 s'écrit en binaire :  11010111 sur  8  bits
# 216 s'écrit en binaire :  11011000 sur  8  bits
# 217 s'écrit en binaire :  11011001 sur  8  bits
# 218 s'écrit en binaire :  11011010 sur  8  bits
# 219 s'écrit en binaire :  11011011 sur  8  bits
# 220 s'écrit en binaire :  11011100 sur  8  bits
# 221 s'écrit en binaire :  11011101 sur  8  bits
# 222 s'écrit en binaire :  11011110 sur  8  bits
# 223 s'écrit en binaire :  11011111 sur  8  bits
# 224 s'écrit en binaire :  11100000 sur  8  bits
# 225 s'écrit en binaire :  11100001 sur  8  bits
# 226 s'écrit en binaire :  11100010 sur  8  bits
# 227 s'écrit en binaire :  11100011 sur  8  bits
# 228 s'écrit en binaire :  11100100 sur  8  bits
# 229 s'écrit en binaire :  11100101 sur  8  bits
# 230 s'écrit en binaire :  11100110 sur  8  bits
# 231 s'écrit en binaire :  11100111 sur  8  bits
# 232 s'écrit en binaire :  11101000 sur  8  bits
# 233 s'écrit en binaire :  11101001 sur  8  bits
# 234 s'écrit en binaire :  11101010 sur  8  bits
# 235 s'écrit en binaire :  11101011 sur  8  bits
# 236 s'écrit en binaire :  11101100 sur  8  bits
# 237 s'écrit en binaire :  11101101 sur  8  bits
# 238 s'écrit en binaire :  11101110 sur  8  bits
# 239 s'écrit en binaire :  11101111 sur  8  bits
# 240 s'écrit en binaire :  11110000 sur  8  bits
# 241 s'écrit en binaire :  11110001 sur  8  bits
# 242 s'écrit en binaire :  11110010 sur  8  bits
# 243 s'écrit en binaire :  11110011 sur  8  bits
# 244 s'écrit en binaire :  11110100 sur  8  bits
# 245 s'écrit en binaire :  11110101 sur  8  bits
# 246 s'écrit en binaire :  11110110 sur  8  bits
# 247 s'écrit en binaire :  11110111 sur  8  bits
# 248 s'écrit en binaire :  11111000 sur  8  bits
# 249 s'écrit en binaire :  11111001 sur  8  bits
# 250 s'écrit en binaire :  11111010 sur  8  bits
# 251 s'écrit en binaire :  11111011 sur  8  bits
# 252 s'écrit en binaire :  11111100 sur  8  bits
# 253 s'écrit en binaire :  11111101 sur  8  bits
# 254 s'écrit en binaire :  11111110 sur  8  bits
# 255 s'écrit en binaire :  11111111 sur  8  bits
# 256 s'écrit en binaire :  100000000 sur  9  bits
# 257 s'écrit en binaire :  100000001 sur  9  bits
# 258 s'écrit en binaire :  100000010 sur  9  bits
# 259 s'écrit en binaire :  100000011 sur  9  bits
# 260 s'écrit en binaire :  100000100 sur  9  bits
# 261 s'écrit en binaire :  100000101 sur  9  bits
# 262 s'écrit en binaire :  100000110 sur  9  bits
# 263 s'écrit en binaire :  100000111 sur  9  bits
# 264 s'écrit en binaire :  100001000 sur  9  bits
# 265 s'écrit en binaire :  100001001 sur  9  bits
# 266 s'écrit en binaire :  100001010 sur  9  bits
# 267 s'écrit en binaire :  100001011 sur  9  bits
# 268 s'écrit en binaire :  100001100 sur  9  bits
# 269 s'écrit en binaire :  100001101 sur  9  bits
# 270 s'écrit en binaire :  100001110 sur  9  bits
# 271 s'écrit en binaire :  100001111 sur  9  bits
# 272 s'écrit en binaire :  100010000 sur  9  bits
# 273 s'écrit en binaire :  100010001 sur  9  bits
# 274 s'écrit en binaire :  100010010 sur  9  bits
# 275 s'écrit en binaire :  100010011 sur  9  bits
# 276 s'écrit en binaire :  100010100 sur  9  bits
# 277 s'écrit en binaire :  100010101 sur  9  bits
# 278 s'écrit en binaire :  100010110 sur  9  bits
# 279 s'écrit en binaire :  100010111 sur  9  bits
# 280 s'écrit en binaire :  100011000 sur  9  bits
# 281 s'écrit en binaire :  100011001 sur  9  bits
# 282 s'écrit en binaire :  100011010 sur  9  bits
# 283 s'écrit en binaire :  100011011 sur  9  bits
# 284 s'écrit en binaire :  100011100 sur  9  bits
# 285 s'écrit en binaire :  100011101 sur  9  bits
# 286 s'écrit en binaire :  100011110 sur  9  bits
# 287 s'écrit en binaire :  100011111 sur  9  bits
# 288 s'écrit en binaire :  100100000 sur  9  bits
# 289 s'écrit en binaire :  100100001 sur  9  bits
# 290 s'écrit en binaire :  100100010 sur  9  bits
# 291 s'écrit en binaire :  100100011 sur  9  bits
# 292 s'écrit en binaire :  100100100 sur  9  bits
# 293 s'écrit en binaire :  100100101 sur  9  bits
# 294 s'écrit en binaire :  100100110 sur  9  bits
# 295 s'écrit en binaire :  100100111 sur  9  bits
# 296 s'écrit en binaire :  100101000 sur  9  bits
# 297 s'écrit en binaire :  100101001 sur  9  bits
# 298 s'écrit en binaire :  100101010 sur  9  bits
# 299 s'écrit en binaire :  100101011 sur  9  bits

# %% [markdown]
# ##Etape 2 :
# Est ce que l'affichage est identique à ce qui est demandé  ?
# Comment résoudre le problème ?
#
# Aide : il faut enlever des caractères à la variable abin
# http://www.python-simple.com/python-langage/chaines-de-caracteres-string.php

# %% [markdown]
# ##Etape 3 :
# On veut enrichir la phrase de synthèse en calculant la longueur de la conversion binaire.
# 0 sécrit en binaire  0  sur  1  bits
# 1 sécrit en binaire  1  sur  1  bits
# 2 sécrit en binaire  10  sur  2  bits
# 3 sécrit en binaire  11  sur  2  bits ....

# %%
#Etape 3:
for a in range( , ):
    #convertir a en binaire et l'affecter à une nouvelle variable
    abin = a
    #Ecrire la phrase de synthese
    print (a)

# %% [markdown]
# ##Etape 4 :
# A l'aide du programme que vous venez d'écrire, convertir en binaire les nombres entre 1 000 000 et 1 000 300

# %%
#Etape 4:
for a in range( , ):
    #convertir a en binaire et l'affecter à une nouvelle variable
    abin = a
    #Ecrire la phrase de synthese
    print (a)

# %% [markdown]
# Est-ce encore lisible ?
# Que peut on faire ?
#
# Existe il d'autres représentation des nombres entiers en informatique ?

# %% [markdown]
# ##Etape 5 :
# Mettez en oeuvre une nouvelle méthode de codage XXXX pour des nombres de 0 à 300 puis de 1 000 000 à 1 000 300

# %%
#Etape 5 : 
for a in range(0, 300):
    #convertir a en binaire et l'affecter à une nouvelle variable
    abin = a
    #Ecrire la phrase de synthese
    print (a)

# %% [markdown]
# ##Etape 6 :
# Reprenez votre programme et modifier la phrase de synthèse pour afficher côte à côté le binaire et le nouveau codage
# exemple :
# 15 sécrit en binaire  1111 et en XXXX  ?

# %%
#Etape 6 : 
for a in range(0, 300):
    #convertir a en binaire et l'affecter à une nouvelle variable
    abin = a
    #Ecrire la phrase de synthese
    print (a)

# %% [markdown]
# Que remarquez vous ?
