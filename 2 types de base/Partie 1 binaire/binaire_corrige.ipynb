# %% [markdown]
# #  Le codage binaire

# %% [markdown]
# ## Rappel : Bibliothèque de référence Python
# https://docs.python.org/fr/3/reference/index.html#reference-index

# %% [markdown]
# ## Objectif du programme :
# ## Etape 1 :
# Ecrire une boucle de 0 à 300 qui écrit la conversion en binaire d'un nombre.
# On obtient en sortie :
#
# 0 sécrit en binaire  0
#
# 1 sécrit en binaire  1
#
# 2 sécrit en binaire  10
#
# 3 sécrit en binaire  11
#
# .....

# %%
#Etape 1 :
for a in range(0 ,300 ):
    #convertir a en binaire et l'affecter à une nouvelle variable
    abin = bin(a)
    #Ecrire la phrase de synthese
    print (a, "s'écrit en binaire : ", abin )

# %% [markdown]
# ## Etape 2 :
# Est ce que l'affichage est identique à ce qui est demandé  ?
# Comment résoudre le problème ?
#
# _Aide :_  il faut enlever des caractères à la variable ``abin``
#
# http://www.python-simple.com/python-langage/chaines-de-caracteres-string.php

# %%
#Etape 2:
for a in range(0 ,300 ):
    #convertir a en binaire et l'affecter à une nouvelle variable
    abin = bin(a)
    #Ecrire la phrase de synthese
    print (a, "s'écrit en binaire : ", abin[2:] )

# %% [markdown]
# ## Etape 3 :
# On veut enrichir la phrase de synthèse en calculant la longueur de la conversion binaire.
# 0 sécrit en binaire  0  sur  1  bits
#
# 1 sécrit en binaire  1  sur  1  bits
#
# 2 sécrit en binaire  10  sur  2  bits
#
# 3 sécrit en binaire  11  sur  2  bits ....

# %%
#Etape 3 :
for a in range(0 ,300 ):
    #convertir a en binaire et l'affecter à une nouvelle variable
    abin = bin(a)
    #Ecrire la phrase de synthese
    print (a, "s'écrit en binaire : ", abin[2:], "sur ", len(abin[2:]) , " bits")

# %% [markdown]
# ## Etape 4 :
# A l'aide du programme que vous venez d'écrire, convertir en binaire les nombres entre 1 000 000 et 1 000 300

# %%
#Etape 4:
for a in range(1000000 ,1000300 ):
    #convertir a en binaire et l'affecter à une nouvelle variable
    abin = bin(a)
    #Ecrire la phrase de synthese  
    print (a, "s'écrit en binaire : ", abin[2:], "sur ", len(abin[2:]) , " bits")
# Out:
# 1000000 s'écrit en binaire :  11110100001001000000 sur  20  bits
# 1000001 s'écrit en binaire :  11110100001001000001 sur  20  bits
# 1000002 s'écrit en binaire :  11110100001001000010 sur  20  bits
# 1000003 s'écrit en binaire :  11110100001001000011 sur  20  bits
# 1000004 s'écrit en binaire :  11110100001001000100 sur  20  bits
# 1000005 s'écrit en binaire :  11110100001001000101 sur  20  bits
# 1000006 s'écrit en binaire :  11110100001001000110 sur  20  bits
# 1000007 s'écrit en binaire :  11110100001001000111 sur  20  bits
# 1000008 s'écrit en binaire :  11110100001001001000 sur  20  bits
# 1000009 s'écrit en binaire :  11110100001001001001 sur  20  bits
# 1000010 s'écrit en binaire :  11110100001001001010 sur  20  bits
# 1000011 s'écrit en binaire :  11110100001001001011 sur  20  bits
# 1000012 s'écrit en binaire :  11110100001001001100 sur  20  bits
# 1000013 s'écrit en binaire :  11110100001001001101 sur  20  bits
# 1000014 s'écrit en binaire :  11110100001001001110 sur  20  bits
# 1000015 s'écrit en binaire :  11110100001001001111 sur  20  bits
# 1000016 s'écrit en binaire :  11110100001001010000 sur  20  bits
# 1000017 s'écrit en binaire :  11110100001001010001 sur  20  bits
# 1000018 s'écrit en binaire :  11110100001001010010 sur  20  bits
# 1000019 s'écrit en binaire :  11110100001001010011 sur  20  bits
# 1000020 s'écrit en binaire :  11110100001001010100 sur  20  bits
# 1000021 s'écrit en binaire :  11110100001001010101 sur  20  bits
# 1000022 s'écrit en binaire :  11110100001001010110 sur  20  bits
# 1000023 s'écrit en binaire :  11110100001001010111 sur  20  bits
# 1000024 s'écrit en binaire :  11110100001001011000 sur  20  bits
# 1000025 s'écrit en binaire :  11110100001001011001 sur  20  bits
# 1000026 s'écrit en binaire :  11110100001001011010 sur  20  bits
# 1000027 s'écrit en binaire :  11110100001001011011 sur  20  bits
# 1000028 s'écrit en binaire :  11110100001001011100 sur  20  bits
# 1000029 s'écrit en binaire :  11110100001001011101 sur  20  bits
# 1000030 s'écrit en binaire :  11110100001001011110 sur  20  bits
# 1000031 s'écrit en binaire :  11110100001001011111 sur  20  bits
# 1000032 s'écrit en binaire :  11110100001001100000 sur  20  bits
# 1000033 s'écrit en binaire :  11110100001001100001 sur  20  bits
# 1000034 s'écrit en binaire :  11110100001001100010 sur  20  bits
# 1000035 s'écrit en binaire :  11110100001001100011 sur  20  bits
# 1000036 s'écrit en binaire :  11110100001001100100 sur  20  bits
# 1000037 s'écrit en binaire :  11110100001001100101 sur  20  bits
# 1000038 s'écrit en binaire :  11110100001001100110 sur  20  bits
# 1000039 s'écrit en binaire :  11110100001001100111 sur  20  bits
# 1000040 s'écrit en binaire :  11110100001001101000 sur  20  bits
# 1000041 s'écrit en binaire :  11110100001001101001 sur  20  bits
# 1000042 s'écrit en binaire :  11110100001001101010 sur  20  bits
# 1000043 s'écrit en binaire :  11110100001001101011 sur  20  bits
# 1000044 s'écrit en binaire :  11110100001001101100 sur  20  bits
# 1000045 s'écrit en binaire :  11110100001001101101 sur  20  bits
# 1000046 s'écrit en binaire :  11110100001001101110 sur  20  bits
# 1000047 s'écrit en binaire :  11110100001001101111 sur  20  bits
# 1000048 s'écrit en binaire :  11110100001001110000 sur  20  bits
# 1000049 s'écrit en binaire :  11110100001001110001 sur  20  bits
# 1000050 s'écrit en binaire :  11110100001001110010 sur  20  bits
# 1000051 s'écrit en binaire :  11110100001001110011 sur  20  bits
# 1000052 s'écrit en binaire :  11110100001001110100 sur  20  bits
# 1000053 s'écrit en binaire :  11110100001001110101 sur  20  bits
# 1000054 s'écrit en binaire :  11110100001001110110 sur  20  bits
# 1000055 s'écrit en binaire :  11110100001001110111 sur  20  bits
# 1000056 s'écrit en binaire :  11110100001001111000 sur  20  bits
# 1000057 s'écrit en binaire :  11110100001001111001 sur  20  bits
# 1000058 s'écrit en binaire :  11110100001001111010 sur  20  bits
# 1000059 s'écrit en binaire :  11110100001001111011 sur  20  bits
# 1000060 s'écrit en binaire :  11110100001001111100 sur  20  bits
# 1000061 s'écrit en binaire :  11110100001001111101 sur  20  bits
# 1000062 s'écrit en binaire :  11110100001001111110 sur  20  bits
# 1000063 s'écrit en binaire :  11110100001001111111 sur  20  bits
# 1000064 s'écrit en binaire :  11110100001010000000 sur  20  bits
# 1000065 s'écrit en binaire :  11110100001010000001 sur  20  bits
# 1000066 s'écrit en binaire :  11110100001010000010 sur  20  bits
# 1000067 s'écrit en binaire :  11110100001010000011 sur  20  bits
# 1000068 s'écrit en binaire :  11110100001010000100 sur  20  bits
# 1000069 s'écrit en binaire :  11110100001010000101 sur  20  bits
# 1000070 s'écrit en binaire :  11110100001010000110 sur  20  bits
# 1000071 s'écrit en binaire :  11110100001010000111 sur  20  bits
# 1000072 s'écrit en binaire :  11110100001010001000 sur  20  bits
# 1000073 s'écrit en binaire :  11110100001010001001 sur  20  bits
# 1000074 s'écrit en binaire :  11110100001010001010 sur  20  bits
# 1000075 s'écrit en binaire :  11110100001010001011 sur  20  bits
# 1000076 s'écrit en binaire :  11110100001010001100 sur  20  bits
# 1000077 s'écrit en binaire :  11110100001010001101 sur  20  bits
# 1000078 s'écrit en binaire :  11110100001010001110 sur  20  bits
# 1000079 s'écrit en binaire :  11110100001010001111 sur  20  bits
# 1000080 s'écrit en binaire :  11110100001010010000 sur  20  bits
# 1000081 s'écrit en binaire :  11110100001010010001 sur  20  bits
# 1000082 s'écrit en binaire :  11110100001010010010 sur  20  bits
# 1000083 s'écrit en binaire :  11110100001010010011 sur  20  bits
# 1000084 s'écrit en binaire :  11110100001010010100 sur  20  bits
# 1000085 s'écrit en binaire :  11110100001010010101 sur  20  bits
# 1000086 s'écrit en binaire :  11110100001010010110 sur  20  bits
# 1000087 s'écrit en binaire :  11110100001010010111 sur  20  bits
# 1000088 s'écrit en binaire :  11110100001010011000 sur  20  bits
# 1000089 s'écrit en binaire :  11110100001010011001 sur  20  bits
# 1000090 s'écrit en binaire :  11110100001010011010 sur  20  bits
# 1000091 s'écrit en binaire :  11110100001010011011 sur  20  bits
# 1000092 s'écrit en binaire :  11110100001010011100 sur  20  bits
# 1000093 s'écrit en binaire :  11110100001010011101 sur  20  bits
# 1000094 s'écrit en binaire :  11110100001010011110 sur  20  bits
# 1000095 s'écrit en binaire :  11110100001010011111 sur  20  bits
# 1000096 s'écrit en binaire :  11110100001010100000 sur  20  bits
# 1000097 s'écrit en binaire :  11110100001010100001 sur  20  bits
# 1000098 s'écrit en binaire :  11110100001010100010 sur  20  bits
# 1000099 s'écrit en binaire :  11110100001010100011 sur  20  bits
# 1000100 s'écrit en binaire :  11110100001010100100 sur  20  bits
# 1000101 s'écrit en binaire :  11110100001010100101 sur  20  bits
# 1000102 s'écrit en binaire :  11110100001010100110 sur  20  bits
# 1000103 s'écrit en binaire :  11110100001010100111 sur  20  bits
# 1000104 s'écrit en binaire :  11110100001010101000 sur  20  bits
# 1000105 s'écrit en binaire :  11110100001010101001 sur  20  bits
# 1000106 s'écrit en binaire :  11110100001010101010 sur  20  bits
# 1000107 s'écrit en binaire :  11110100001010101011 sur  20  bits
# 1000108 s'écrit en binaire :  11110100001010101100 sur  20  bits
# 1000109 s'écrit en binaire :  11110100001010101101 sur  20  bits
# 1000110 s'écrit en binaire :  11110100001010101110 sur  20  bits
# 1000111 s'écrit en binaire :  11110100001010101111 sur  20  bits
# 1000112 s'écrit en binaire :  11110100001010110000 sur  20  bits
# 1000113 s'écrit en binaire :  11110100001010110001 sur  20  bits
# 1000114 s'écrit en binaire :  11110100001010110010 sur  20  bits
# 1000115 s'écrit en binaire :  11110100001010110011 sur  20  bits
# 1000116 s'écrit en binaire :  11110100001010110100 sur  20  bits
# 1000117 s'écrit en binaire :  11110100001010110101 sur  20  bits
# 1000118 s'écrit en binaire :  11110100001010110110 sur  20  bits
# 1000119 s'écrit en binaire :  11110100001010110111 sur  20  bits
# 1000120 s'écrit en binaire :  11110100001010111000 sur  20  bits
# 1000121 s'écrit en binaire :  11110100001010111001 sur  20  bits
# 1000122 s'écrit en binaire :  11110100001010111010 sur  20  bits
# 1000123 s'écrit en binaire :  11110100001010111011 sur  20  bits
# 1000124 s'écrit en binaire :  11110100001010111100 sur  20  bits
# 1000125 s'écrit en binaire :  11110100001010111101 sur  20  bits
# 1000126 s'écrit en binaire :  11110100001010111110 sur  20  bits
# 1000127 s'écrit en binaire :  11110100001010111111 sur  20  bits
# 1000128 s'écrit en binaire :  11110100001011000000 sur  20  bits
# 1000129 s'écrit en binaire :  11110100001011000001 sur  20  bits
# 1000130 s'écrit en binaire :  11110100001011000010 sur  20  bits
# 1000131 s'écrit en binaire :  11110100001011000011 sur  20  bits
# 1000132 s'écrit en binaire :  11110100001011000100 sur  20  bits
# 1000133 s'écrit en binaire :  11110100001011000101 sur  20  bits
# 1000134 s'écrit en binaire :  11110100001011000110 sur  20  bits
# 1000135 s'écrit en binaire :  11110100001011000111 sur  20  bits
# 1000136 s'écrit en binaire :  11110100001011001000 sur  20  bits
# 1000137 s'écrit en binaire :  11110100001011001001 sur  20  bits
# 1000138 s'écrit en binaire :  11110100001011001010 sur  20  bits
# 1000139 s'écrit en binaire :  11110100001011001011 sur  20  bits
# 1000140 s'écrit en binaire :  11110100001011001100 sur  20  bits
# 1000141 s'écrit en binaire :  11110100001011001101 sur  20  bits
# 1000142 s'écrit en binaire :  11110100001011001110 sur  20  bits
# 1000143 s'écrit en binaire :  11110100001011001111 sur  20  bits
# 1000144 s'écrit en binaire :  11110100001011010000 sur  20  bits
# 1000145 s'écrit en binaire :  11110100001011010001 sur  20  bits
# 1000146 s'écrit en binaire :  11110100001011010010 sur  20  bits
# 1000147 s'écrit en binaire :  11110100001011010011 sur  20  bits
# 1000148 s'écrit en binaire :  11110100001011010100 sur  20  bits
# 1000149 s'écrit en binaire :  11110100001011010101 sur  20  bits
# 1000150 s'écrit en binaire :  11110100001011010110 sur  20  bits
# 1000151 s'écrit en binaire :  11110100001011010111 sur  20  bits
# 1000152 s'écrit en binaire :  11110100001011011000 sur  20  bits
# 1000153 s'écrit en binaire :  11110100001011011001 sur  20  bits
# 1000154 s'écrit en binaire :  11110100001011011010 sur  20  bits
# 1000155 s'écrit en binaire :  11110100001011011011 sur  20  bits
# 1000156 s'écrit en binaire :  11110100001011011100 sur  20  bits
# 1000157 s'écrit en binaire :  11110100001011011101 sur  20  bits
# 1000158 s'écrit en binaire :  11110100001011011110 sur  20  bits
# 1000159 s'écrit en binaire :  11110100001011011111 sur  20  bits
# 1000160 s'écrit en binaire :  11110100001011100000 sur  20  bits
# 1000161 s'écrit en binaire :  11110100001011100001 sur  20  bits
# 1000162 s'écrit en binaire :  11110100001011100010 sur  20  bits
# 1000163 s'écrit en binaire :  11110100001011100011 sur  20  bits
# 1000164 s'écrit en binaire :  11110100001011100100 sur  20  bits
# 1000165 s'écrit en binaire :  11110100001011100101 sur  20  bits
# 1000166 s'écrit en binaire :  11110100001011100110 sur  20  bits
# 1000167 s'écrit en binaire :  11110100001011100111 sur  20  bits
# 1000168 s'écrit en binaire :  11110100001011101000 sur  20  bits
# 1000169 s'écrit en binaire :  11110100001011101001 sur  20  bits
# 1000170 s'écrit en binaire :  11110100001011101010 sur  20  bits
# 1000171 s'écrit en binaire :  11110100001011101011 sur  20  bits
# 1000172 s'écrit en binaire :  11110100001011101100 sur  20  bits
# 1000173 s'écrit en binaire :  11110100001011101101 sur  20  bits
# 1000174 s'écrit en binaire :  11110100001011101110 sur  20  bits
# 1000175 s'écrit en binaire :  11110100001011101111 sur  20  bits
# 1000176 s'écrit en binaire :  11110100001011110000 sur  20  bits
# 1000177 s'écrit en binaire :  11110100001011110001 sur  20  bits
# 1000178 s'écrit en binaire :  11110100001011110010 sur  20  bits
# 1000179 s'écrit en binaire :  11110100001011110011 sur  20  bits
# 1000180 s'écrit en binaire :  11110100001011110100 sur  20  bits
# 1000181 s'écrit en binaire :  11110100001011110101 sur  20  bits
# 1000182 s'écrit en binaire :  11110100001011110110 sur  20  bits
# 1000183 s'écrit en binaire :  11110100001011110111 sur  20  bits
# 1000184 s'écrit en binaire :  11110100001011111000 sur  20  bits
# 1000185 s'écrit en binaire :  11110100001011111001 sur  20  bits
# 1000186 s'écrit en binaire :  11110100001011111010 sur  20  bits
# 1000187 s'écrit en binaire :  11110100001011111011 sur  20  bits
# 1000188 s'écrit en binaire :  11110100001011111100 sur  20  bits
# 1000189 s'écrit en binaire :  11110100001011111101 sur  20  bits
# 1000190 s'écrit en binaire :  11110100001011111110 sur  20  bits
# 1000191 s'écrit en binaire :  11110100001011111111 sur  20  bits
# 1000192 s'écrit en binaire :  11110100001100000000 sur  20  bits
# 1000193 s'écrit en binaire :  11110100001100000001 sur  20  bits
# 1000194 s'écrit en binaire :  11110100001100000010 sur  20  bits
# 1000195 s'écrit en binaire :  11110100001100000011 sur  20  bits
# 1000196 s'écrit en binaire :  11110100001100000100 sur  20  bits
# 1000197 s'écrit en binaire :  11110100001100000101 sur  20  bits
# 1000198 s'écrit en binaire :  11110100001100000110 sur  20  bits
# 1000199 s'écrit en binaire :  11110100001100000111 sur  20  bits
# 1000200 s'écrit en binaire :  11110100001100001000 sur  20  bits
# 1000201 s'écrit en binaire :  11110100001100001001 sur  20  bits
# 1000202 s'écrit en binaire :  11110100001100001010 sur  20  bits
# 1000203 s'écrit en binaire :  11110100001100001011 sur  20  bits
# 1000204 s'écrit en binaire :  11110100001100001100 sur  20  bits
# 1000205 s'écrit en binaire :  11110100001100001101 sur  20  bits
# 1000206 s'écrit en binaire :  11110100001100001110 sur  20  bits
# 1000207 s'écrit en binaire :  11110100001100001111 sur  20  bits
# 1000208 s'écrit en binaire :  11110100001100010000 sur  20  bits
# 1000209 s'écrit en binaire :  11110100001100010001 sur  20  bits
# 1000210 s'écrit en binaire :  11110100001100010010 sur  20  bits
# 1000211 s'écrit en binaire :  11110100001100010011 sur  20  bits
# 1000212 s'écrit en binaire :  11110100001100010100 sur  20  bits
# 1000213 s'écrit en binaire :  11110100001100010101 sur  20  bits
# 1000214 s'écrit en binaire :  11110100001100010110 sur  20  bits
# 1000215 s'écrit en binaire :  11110100001100010111 sur  20  bits
# 1000216 s'écrit en binaire :  11110100001100011000 sur  20  bits
# 1000217 s'écrit en binaire :  11110100001100011001 sur  20  bits
# 1000218 s'écrit en binaire :  11110100001100011010 sur  20  bits
# 1000219 s'écrit en binaire :  11110100001100011011 sur  20  bits
# 1000220 s'écrit en binaire :  11110100001100011100 sur  20  bits
# 1000221 s'écrit en binaire :  11110100001100011101 sur  20  bits
# 1000222 s'écrit en binaire :  11110100001100011110 sur  20  bits
# 1000223 s'écrit en binaire :  11110100001100011111 sur  20  bits
# 1000224 s'écrit en binaire :  11110100001100100000 sur  20  bits
# 1000225 s'écrit en binaire :  11110100001100100001 sur  20  bits
# 1000226 s'écrit en binaire :  11110100001100100010 sur  20  bits
# 1000227 s'écrit en binaire :  11110100001100100011 sur  20  bits
# 1000228 s'écrit en binaire :  11110100001100100100 sur  20  bits
# 1000229 s'écrit en binaire :  11110100001100100101 sur  20  bits
# 1000230 s'écrit en binaire :  11110100001100100110 sur  20  bits
# 1000231 s'écrit en binaire :  11110100001100100111 sur  20  bits
# 1000232 s'écrit en binaire :  11110100001100101000 sur  20  bits
# 1000233 s'écrit en binaire :  11110100001100101001 sur  20  bits
# 1000234 s'écrit en binaire :  11110100001100101010 sur  20  bits
# 1000235 s'écrit en binaire :  11110100001100101011 sur  20  bits
# 1000236 s'écrit en binaire :  11110100001100101100 sur  20  bits
# 1000237 s'écrit en binaire :  11110100001100101101 sur  20  bits
# 1000238 s'écrit en binaire :  11110100001100101110 sur  20  bits
# 1000239 s'écrit en binaire :  11110100001100101111 sur  20  bits
# 1000240 s'écrit en binaire :  11110100001100110000 sur  20  bits
# 1000241 s'écrit en binaire :  11110100001100110001 sur  20  bits
# 1000242 s'écrit en binaire :  11110100001100110010 sur  20  bits
# 1000243 s'écrit en binaire :  11110100001100110011 sur  20  bits
# 1000244 s'écrit en binaire :  11110100001100110100 sur  20  bits
# 1000245 s'écrit en binaire :  11110100001100110101 sur  20  bits
# 1000246 s'écrit en binaire :  11110100001100110110 sur  20  bits
# 1000247 s'écrit en binaire :  11110100001100110111 sur  20  bits
# 1000248 s'écrit en binaire :  11110100001100111000 sur  20  bits
# 1000249 s'écrit en binaire :  11110100001100111001 sur  20  bits
# 1000250 s'écrit en binaire :  11110100001100111010 sur  20  bits
# 1000251 s'écrit en binaire :  11110100001100111011 sur  20  bits
# 1000252 s'écrit en binaire :  11110100001100111100 sur  20  bits
# 1000253 s'écrit en binaire :  11110100001100111101 sur  20  bits
# 1000254 s'écrit en binaire :  11110100001100111110 sur  20  bits
# 1000255 s'écrit en binaire :  11110100001100111111 sur  20  bits
# 1000256 s'écrit en binaire :  11110100001101000000 sur  20  bits
# 1000257 s'écrit en binaire :  11110100001101000001 sur  20  bits
# 1000258 s'écrit en binaire :  11110100001101000010 sur  20  bits
# 1000259 s'écrit en binaire :  11110100001101000011 sur  20  bits
# 1000260 s'écrit en binaire :  11110100001101000100 sur  20  bits
# 1000261 s'écrit en binaire :  11110100001101000101 sur  20  bits
# 1000262 s'écrit en binaire :  11110100001101000110 sur  20  bits
# 1000263 s'écrit en binaire :  11110100001101000111 sur  20  bits
# 1000264 s'écrit en binaire :  11110100001101001000 sur  20  bits
# 1000265 s'écrit en binaire :  11110100001101001001 sur  20  bits
# 1000266 s'écrit en binaire :  11110100001101001010 sur  20  bits
# 1000267 s'écrit en binaire :  11110100001101001011 sur  20  bits
# 1000268 s'écrit en binaire :  11110100001101001100 sur  20  bits
# 1000269 s'écrit en binaire :  11110100001101001101 sur  20  bits
# 1000270 s'écrit en binaire :  11110100001101001110 sur  20  bits
# 1000271 s'écrit en binaire :  11110100001101001111 sur  20  bits
# 1000272 s'écrit en binaire :  11110100001101010000 sur  20  bits
# 1000273 s'écrit en binaire :  11110100001101010001 sur  20  bits
# 1000274 s'écrit en binaire :  11110100001101010010 sur  20  bits
# 1000275 s'écrit en binaire :  11110100001101010011 sur  20  bits
# 1000276 s'écrit en binaire :  11110100001101010100 sur  20  bits
# 1000277 s'écrit en binaire :  11110100001101010101 sur  20  bits
# 1000278 s'écrit en binaire :  11110100001101010110 sur  20  bits
# 1000279 s'écrit en binaire :  11110100001101010111 sur  20  bits
# 1000280 s'écrit en binaire :  11110100001101011000 sur  20  bits
# 1000281 s'écrit en binaire :  11110100001101011001 sur  20  bits
# 1000282 s'écrit en binaire :  11110100001101011010 sur  20  bits
# 1000283 s'écrit en binaire :  11110100001101011011 sur  20  bits
# 1000284 s'écrit en binaire :  11110100001101011100 sur  20  bits
# 1000285 s'écrit en binaire :  11110100001101011101 sur  20  bits
# 1000286 s'écrit en binaire :  11110100001101011110 sur  20  bits
# 1000287 s'écrit en binaire :  11110100001101011111 sur  20  bits
# 1000288 s'écrit en binaire :  11110100001101100000 sur  20  bits
# 1000289 s'écrit en binaire :  11110100001101100001 sur  20  bits
# 1000290 s'écrit en binaire :  11110100001101100010 sur  20  bits
# 1000291 s'écrit en binaire :  11110100001101100011 sur  20  bits
# 1000292 s'écrit en binaire :  11110100001101100100 sur  20  bits
# 1000293 s'écrit en binaire :  11110100001101100101 sur  20  bits
# 1000294 s'écrit en binaire :  11110100001101100110 sur  20  bits
# 1000295 s'écrit en binaire :  11110100001101100111 sur  20  bits
# 1000296 s'écrit en binaire :  11110100001101101000 sur  20  bits
# 1000297 s'écrit en binaire :  11110100001101101001 sur  20  bits
# 1000298 s'écrit en binaire :  11110100001101101010 sur  20  bits
# 1000299 s'écrit en binaire :  11110100001101101011 sur  20  bits

# %% [markdown]
# Est-ce encore lisible ?
# Que peut on faire ?
#
# Existe il d'autres représentation des nombres entiers en informatique ?

# %% [markdown]
# ## Etape 5 :
# Mettez en oeuvre une nouvelle méthode de codage **hexadecimal** pour des nombres de 0 à 300 puis de 1 000 000 à 1 000 300
#
# Ce nouveau codage se nomme **hexadecimal**.

# %%
#Etape 5 : 
for a in range(1000000 ,1000300 ):
    #convertir a en binaire et l'affecter à une nouvelle variable
    ahex = hex(a)
    #Ecrire la phrase de synthese  
    print (a, "s'écrit en hexadecimal : ", ahex[2:], "sur ", len(ahex[2:]) , " bits")
# Out:
# 1000000 s'écrit en hexadecimal :  f4240 sur  5  bits
# 1000001 s'écrit en hexadecimal :  f4241 sur  5  bits
# 1000002 s'écrit en hexadecimal :  f4242 sur  5  bits
# 1000003 s'écrit en hexadecimal :  f4243 sur  5  bits
# 1000004 s'écrit en hexadecimal :  f4244 sur  5  bits
# 1000005 s'écrit en hexadecimal :  f4245 sur  5  bits
# 1000006 s'écrit en hexadecimal :  f4246 sur  5  bits
# 1000007 s'écrit en hexadecimal :  f4247 sur  5  bits
# 1000008 s'écrit en hexadecimal :  f4248 sur  5  bits
# 1000009 s'écrit en hexadecimal :  f4249 sur  5  bits
# 1000010 s'écrit en hexadecimal :  f424a sur  5  bits
# 1000011 s'écrit en hexadecimal :  f424b sur  5  bits
# 1000012 s'écrit en hexadecimal :  f424c sur  5  bits
# 1000013 s'écrit en hexadecimal :  f424d sur  5  bits
# 1000014 s'écrit en hexadecimal :  f424e sur  5  bits
# 1000015 s'écrit en hexadecimal :  f424f sur  5  bits
# 1000016 s'écrit en hexadecimal :  f4250 sur  5  bits
# 1000017 s'écrit en hexadecimal :  f4251 sur  5  bits
# 1000018 s'écrit en hexadecimal :  f4252 sur  5  bits
# 1000019 s'écrit en hexadecimal :  f4253 sur  5  bits
# 1000020 s'écrit en hexadecimal :  f4254 sur  5  bits
# 1000021 s'écrit en hexadecimal :  f4255 sur  5  bits
# 1000022 s'écrit en hexadecimal :  f4256 sur  5  bits
# 1000023 s'écrit en hexadecimal :  f4257 sur  5  bits
# 1000024 s'écrit en hexadecimal :  f4258 sur  5  bits
# 1000025 s'écrit en hexadecimal :  f4259 sur  5  bits
# 1000026 s'écrit en hexadecimal :  f425a sur  5  bits
# 1000027 s'écrit en hexadecimal :  f425b sur  5  bits
# 1000028 s'écrit en hexadecimal :  f425c sur  5  bits
# 1000029 s'écrit en hexadecimal :  f425d sur  5  bits
# 1000030 s'écrit en hexadecimal :  f425e sur  5  bits
# 1000031 s'écrit en hexadecimal :  f425f sur  5  bits
# 1000032 s'écrit en hexadecimal :  f4260 sur  5  bits
# 1000033 s'écrit en hexadecimal :  f4261 sur  5  bits
# 1000034 s'écrit en hexadecimal :  f4262 sur  5  bits
# 1000035 s'écrit en hexadecimal :  f4263 sur  5  bits
# 1000036 s'écrit en hexadecimal :  f4264 sur  5  bits
# 1000037 s'écrit en hexadecimal :  f4265 sur  5  bits
# 1000038 s'écrit en hexadecimal :  f4266 sur  5  bits
# 1000039 s'écrit en hexadecimal :  f4267 sur  5  bits
# 1000040 s'écrit en hexadecimal :  f4268 sur  5  bits
# 1000041 s'écrit en hexadecimal :  f4269 sur  5  bits
# 1000042 s'écrit en hexadecimal :  f426a sur  5  bits
# 1000043 s'écrit en hexadecimal :  f426b sur  5  bits
# 1000044 s'écrit en hexadecimal :  f426c sur  5  bits
# 1000045 s'écrit en hexadecimal :  f426d sur  5  bits
# 1000046 s'écrit en hexadecimal :  f426e sur  5  bits
# 1000047 s'écrit en hexadecimal :  f426f sur  5  bits
# 1000048 s'écrit en hexadecimal :  f4270 sur  5  bits
# 1000049 s'écrit en hexadecimal :  f4271 sur  5  bits
# 1000050 s'écrit en hexadecimal :  f4272 sur  5  bits
# 1000051 s'écrit en hexadecimal :  f4273 sur  5  bits
# 1000052 s'écrit en hexadecimal :  f4274 sur  5  bits
# 1000053 s'écrit en hexadecimal :  f4275 sur  5  bits
# 1000054 s'écrit en hexadecimal :  f4276 sur  5  bits
# 1000055 s'écrit en hexadecimal :  f4277 sur  5  bits
# 1000056 s'écrit en hexadecimal :  f4278 sur  5  bits
# 1000057 s'écrit en hexadecimal :  f4279 sur  5  bits
# 1000058 s'écrit en hexadecimal :  f427a sur  5  bits
# 1000059 s'écrit en hexadecimal :  f427b sur  5  bits
# 1000060 s'écrit en hexadecimal :  f427c sur  5  bits
# 1000061 s'écrit en hexadecimal :  f427d sur  5  bits
# 1000062 s'écrit en hexadecimal :  f427e sur  5  bits
# 1000063 s'écrit en hexadecimal :  f427f sur  5  bits
# 1000064 s'écrit en hexadecimal :  f4280 sur  5  bits
# 1000065 s'écrit en hexadecimal :  f4281 sur  5  bits
# 1000066 s'écrit en hexadecimal :  f4282 sur  5  bits
# 1000067 s'écrit en hexadecimal :  f4283 sur  5  bits
# 1000068 s'écrit en hexadecimal :  f4284 sur  5  bits
# 1000069 s'écrit en hexadecimal :  f4285 sur  5  bits
# 1000070 s'écrit en hexadecimal :  f4286 sur  5  bits
# 1000071 s'écrit en hexadecimal :  f4287 sur  5  bits
# 1000072 s'écrit en hexadecimal :  f4288 sur  5  bits
# 1000073 s'écrit en hexadecimal :  f4289 sur  5  bits
# 1000074 s'écrit en hexadecimal :  f428a sur  5  bits
# 1000075 s'écrit en hexadecimal :  f428b sur  5  bits
# 1000076 s'écrit en hexadecimal :  f428c sur  5  bits
# 1000077 s'écrit en hexadecimal :  f428d sur  5  bits
# 1000078 s'écrit en hexadecimal :  f428e sur  5  bits
# 1000079 s'écrit en hexadecimal :  f428f sur  5  bits
# 1000080 s'écrit en hexadecimal :  f4290 sur  5  bits
# 1000081 s'écrit en hexadecimal :  f4291 sur  5  bits
# 1000082 s'écrit en hexadecimal :  f4292 sur  5  bits
# 1000083 s'écrit en hexadecimal :  f4293 sur  5  bits
# 1000084 s'écrit en hexadecimal :  f4294 sur  5  bits
# 1000085 s'écrit en hexadecimal :  f4295 sur  5  bits
# 1000086 s'écrit en hexadecimal :  f4296 sur  5  bits
# 1000087 s'écrit en hexadecimal :  f4297 sur  5  bits
# 1000088 s'écrit en hexadecimal :  f4298 sur  5  bits
# 1000089 s'écrit en hexadecimal :  f4299 sur  5  bits
# 1000090 s'écrit en hexadecimal :  f429a sur  5  bits
# 1000091 s'écrit en hexadecimal :  f429b sur  5  bits
# 1000092 s'écrit en hexadecimal :  f429c sur  5  bits
# 1000093 s'écrit en hexadecimal :  f429d sur  5  bits
# 1000094 s'écrit en hexadecimal :  f429e sur  5  bits
# 1000095 s'écrit en hexadecimal :  f429f sur  5  bits
# 1000096 s'écrit en hexadecimal :  f42a0 sur  5  bits
# 1000097 s'écrit en hexadecimal :  f42a1 sur  5  bits
# 1000098 s'écrit en hexadecimal :  f42a2 sur  5  bits
# 1000099 s'écrit en hexadecimal :  f42a3 sur  5  bits
# 1000100 s'écrit en hexadecimal :  f42a4 sur  5  bits
# 1000101 s'écrit en hexadecimal :  f42a5 sur  5  bits
# 1000102 s'écrit en hexadecimal :  f42a6 sur  5  bits
# 1000103 s'écrit en hexadecimal :  f42a7 sur  5  bits
# 1000104 s'écrit en hexadecimal :  f42a8 sur  5  bits
# 1000105 s'écrit en hexadecimal :  f42a9 sur  5  bits
# 1000106 s'écrit en hexadecimal :  f42aa sur  5  bits
# 1000107 s'écrit en hexadecimal :  f42ab sur  5  bits
# 1000108 s'écrit en hexadecimal :  f42ac sur  5  bits
# 1000109 s'écrit en hexadecimal :  f42ad sur  5  bits
# 1000110 s'écrit en hexadecimal :  f42ae sur  5  bits
# 1000111 s'écrit en hexadecimal :  f42af sur  5  bits
# 1000112 s'écrit en hexadecimal :  f42b0 sur  5  bits
# 1000113 s'écrit en hexadecimal :  f42b1 sur  5  bits
# 1000114 s'écrit en hexadecimal :  f42b2 sur  5  bits
# 1000115 s'écrit en hexadecimal :  f42b3 sur  5  bits
# 1000116 s'écrit en hexadecimal :  f42b4 sur  5  bits
# 1000117 s'écrit en hexadecimal :  f42b5 sur  5  bits
# 1000118 s'écrit en hexadecimal :  f42b6 sur  5  bits
# 1000119 s'écrit en hexadecimal :  f42b7 sur  5  bits
# 1000120 s'écrit en hexadecimal :  f42b8 sur  5  bits
# 1000121 s'écrit en hexadecimal :  f42b9 sur  5  bits
# 1000122 s'écrit en hexadecimal :  f42ba sur  5  bits
# 1000123 s'écrit en hexadecimal :  f42bb sur  5  bits
# 1000124 s'écrit en hexadecimal :  f42bc sur  5  bits
# 1000125 s'écrit en hexadecimal :  f42bd sur  5  bits
# 1000126 s'écrit en hexadecimal :  f42be sur  5  bits
# 1000127 s'écrit en hexadecimal :  f42bf sur  5  bits
# 1000128 s'écrit en hexadecimal :  f42c0 sur  5  bits
# 1000129 s'écrit en hexadecimal :  f42c1 sur  5  bits
# 1000130 s'écrit en hexadecimal :  f42c2 sur  5  bits
# 1000131 s'écrit en hexadecimal :  f42c3 sur  5  bits
# 1000132 s'écrit en hexadecimal :  f42c4 sur  5  bits
# 1000133 s'écrit en hexadecimal :  f42c5 sur  5  bits
# 1000134 s'écrit en hexadecimal :  f42c6 sur  5  bits
# 1000135 s'écrit en hexadecimal :  f42c7 sur  5  bits
# 1000136 s'écrit en hexadecimal :  f42c8 sur  5  bits
# 1000137 s'écrit en hexadecimal :  f42c9 sur  5  bits
# 1000138 s'écrit en hexadecimal :  f42ca sur  5  bits
# 1000139 s'écrit en hexadecimal :  f42cb sur  5  bits
# 1000140 s'écrit en hexadecimal :  f42cc sur  5  bits
# 1000141 s'écrit en hexadecimal :  f42cd sur  5  bits
# 1000142 s'écrit en hexadecimal :  f42ce sur  5  bits
# 1000143 s'écrit en hexadecimal :  f42cf sur  5  bits
# 1000144 s'écrit en hexadecimal :  f42d0 sur  5  bits
# 1000145 s'écrit en hexadecimal :  f42d1 sur  5  bits
# 1000146 s'écrit en hexadecimal :  f42d2 sur  5  bits
# 1000147 s'écrit en hexadecimal :  f42d3 sur  5  bits
# 1000148 s'écrit en hexadecimal :  f42d4 sur  5  bits
# 1000149 s'écrit en hexadecimal :  f42d5 sur  5  bits
# 1000150 s'écrit en hexadecimal :  f42d6 sur  5  bits
# 1000151 s'écrit en hexadecimal :  f42d7 sur  5  bits
# 1000152 s'écrit en hexadecimal :  f42d8 sur  5  bits
# 1000153 s'écrit en hexadecimal :  f42d9 sur  5  bits
# 1000154 s'écrit en hexadecimal :  f42da sur  5  bits
# 1000155 s'écrit en hexadecimal :  f42db sur  5  bits
# 1000156 s'écrit en hexadecimal :  f42dc sur  5  bits
# 1000157 s'écrit en hexadecimal :  f42dd sur  5  bits
# 1000158 s'écrit en hexadecimal :  f42de sur  5  bits
# 1000159 s'écrit en hexadecimal :  f42df sur  5  bits
# 1000160 s'écrit en hexadecimal :  f42e0 sur  5  bits
# 1000161 s'écrit en hexadecimal :  f42e1 sur  5  bits
# 1000162 s'écrit en hexadecimal :  f42e2 sur  5  bits
# 1000163 s'écrit en hexadecimal :  f42e3 sur  5  bits
# 1000164 s'écrit en hexadecimal :  f42e4 sur  5  bits
# 1000165 s'écrit en hexadecimal :  f42e5 sur  5  bits
# 1000166 s'écrit en hexadecimal :  f42e6 sur  5  bits
# 1000167 s'écrit en hexadecimal :  f42e7 sur  5  bits
# 1000168 s'écrit en hexadecimal :  f42e8 sur  5  bits
# 1000169 s'écrit en hexadecimal :  f42e9 sur  5  bits
# 1000170 s'écrit en hexadecimal :  f42ea sur  5  bits
# 1000171 s'écrit en hexadecimal :  f42eb sur  5  bits
# 1000172 s'écrit en hexadecimal :  f42ec sur  5  bits
# 1000173 s'écrit en hexadecimal :  f42ed sur  5  bits
# 1000174 s'écrit en hexadecimal :  f42ee sur  5  bits
# 1000175 s'écrit en hexadecimal :  f42ef sur  5  bits
# 1000176 s'écrit en hexadecimal :  f42f0 sur  5  bits
# 1000177 s'écrit en hexadecimal :  f42f1 sur  5  bits
# 1000178 s'écrit en hexadecimal :  f42f2 sur  5  bits
# 1000179 s'écrit en hexadecimal :  f42f3 sur  5  bits
# 1000180 s'écrit en hexadecimal :  f42f4 sur  5  bits
# 1000181 s'écrit en hexadecimal :  f42f5 sur  5  bits
# 1000182 s'écrit en hexadecimal :  f42f6 sur  5  bits
# 1000183 s'écrit en hexadecimal :  f42f7 sur  5  bits
# 1000184 s'écrit en hexadecimal :  f42f8 sur  5  bits
# 1000185 s'écrit en hexadecimal :  f42f9 sur  5  bits
# 1000186 s'écrit en hexadecimal :  f42fa sur  5  bits
# 1000187 s'écrit en hexadecimal :  f42fb sur  5  bits
# 1000188 s'écrit en hexadecimal :  f42fc sur  5  bits
# 1000189 s'écrit en hexadecimal :  f42fd sur  5  bits
# 1000190 s'écrit en hexadecimal :  f42fe sur  5  bits
# 1000191 s'écrit en hexadecimal :  f42ff sur  5  bits
# 1000192 s'écrit en hexadecimal :  f4300 sur  5  bits
# 1000193 s'écrit en hexadecimal :  f4301 sur  5  bits
# 1000194 s'écrit en hexadecimal :  f4302 sur  5  bits
# 1000195 s'écrit en hexadecimal :  f4303 sur  5  bits
# 1000196 s'écrit en hexadecimal :  f4304 sur  5  bits
# 1000197 s'écrit en hexadecimal :  f4305 sur  5  bits
# 1000198 s'écrit en hexadecimal :  f4306 sur  5  bits
# 1000199 s'écrit en hexadecimal :  f4307 sur  5  bits
# 1000200 s'écrit en hexadecimal :  f4308 sur  5  bits
# 1000201 s'écrit en hexadecimal :  f4309 sur  5  bits
# 1000202 s'écrit en hexadecimal :  f430a sur  5  bits
# 1000203 s'écrit en hexadecimal :  f430b sur  5  bits
# 1000204 s'écrit en hexadecimal :  f430c sur  5  bits
# 1000205 s'écrit en hexadecimal :  f430d sur  5  bits
# 1000206 s'écrit en hexadecimal :  f430e sur  5  bits
# 1000207 s'écrit en hexadecimal :  f430f sur  5  bits
# 1000208 s'écrit en hexadecimal :  f4310 sur  5  bits
# 1000209 s'écrit en hexadecimal :  f4311 sur  5  bits
# 1000210 s'écrit en hexadecimal :  f4312 sur  5  bits
# 1000211 s'écrit en hexadecimal :  f4313 sur  5  bits
# 1000212 s'écrit en hexadecimal :  f4314 sur  5  bits
# 1000213 s'écrit en hexadecimal :  f4315 sur  5  bits
# 1000214 s'écrit en hexadecimal :  f4316 sur  5  bits
# 1000215 s'écrit en hexadecimal :  f4317 sur  5  bits
# 1000216 s'écrit en hexadecimal :  f4318 sur  5  bits
# 1000217 s'écrit en hexadecimal :  f4319 sur  5  bits
# 1000218 s'écrit en hexadecimal :  f431a sur  5  bits
# 1000219 s'écrit en hexadecimal :  f431b sur  5  bits
# 1000220 s'écrit en hexadecimal :  f431c sur  5  bits
# 1000221 s'écrit en hexadecimal :  f431d sur  5  bits
# 1000222 s'écrit en hexadecimal :  f431e sur  5  bits
# 1000223 s'écrit en hexadecimal :  f431f sur  5  bits
# 1000224 s'écrit en hexadecimal :  f4320 sur  5  bits
# 1000225 s'écrit en hexadecimal :  f4321 sur  5  bits
# 1000226 s'écrit en hexadecimal :  f4322 sur  5  bits
# 1000227 s'écrit en hexadecimal :  f4323 sur  5  bits
# 1000228 s'écrit en hexadecimal :  f4324 sur  5  bits
# 1000229 s'écrit en hexadecimal :  f4325 sur  5  bits
# 1000230 s'écrit en hexadecimal :  f4326 sur  5  bits
# 1000231 s'écrit en hexadecimal :  f4327 sur  5  bits
# 1000232 s'écrit en hexadecimal :  f4328 sur  5  bits
# 1000233 s'écrit en hexadecimal :  f4329 sur  5  bits
# 1000234 s'écrit en hexadecimal :  f432a sur  5  bits
# 1000235 s'écrit en hexadecimal :  f432b sur  5  bits
# 1000236 s'écrit en hexadecimal :  f432c sur  5  bits
# 1000237 s'écrit en hexadecimal :  f432d sur  5  bits
# 1000238 s'écrit en hexadecimal :  f432e sur  5  bits
# 1000239 s'écrit en hexadecimal :  f432f sur  5  bits
# 1000240 s'écrit en hexadecimal :  f4330 sur  5  bits
# 1000241 s'écrit en hexadecimal :  f4331 sur  5  bits
# 1000242 s'écrit en hexadecimal :  f4332 sur  5  bits
# 1000243 s'écrit en hexadecimal :  f4333 sur  5  bits
# 1000244 s'écrit en hexadecimal :  f4334 sur  5  bits
# 1000245 s'écrit en hexadecimal :  f4335 sur  5  bits
# 1000246 s'écrit en hexadecimal :  f4336 sur  5  bits
# 1000247 s'écrit en hexadecimal :  f4337 sur  5  bits
# 1000248 s'écrit en hexadecimal :  f4338 sur  5  bits
# 1000249 s'écrit en hexadecimal :  f4339 sur  5  bits
# 1000250 s'écrit en hexadecimal :  f433a sur  5  bits
# 1000251 s'écrit en hexadecimal :  f433b sur  5  bits
# 1000252 s'écrit en hexadecimal :  f433c sur  5  bits
# 1000253 s'écrit en hexadecimal :  f433d sur  5  bits
# 1000254 s'écrit en hexadecimal :  f433e sur  5  bits
# 1000255 s'écrit en hexadecimal :  f433f sur  5  bits
# 1000256 s'écrit en hexadecimal :  f4340 sur  5  bits
# 1000257 s'écrit en hexadecimal :  f4341 sur  5  bits
# 1000258 s'écrit en hexadecimal :  f4342 sur  5  bits
# 1000259 s'écrit en hexadecimal :  f4343 sur  5  bits
# 1000260 s'écrit en hexadecimal :  f4344 sur  5  bits
# 1000261 s'écrit en hexadecimal :  f4345 sur  5  bits
# 1000262 s'écrit en hexadecimal :  f4346 sur  5  bits
# 1000263 s'écrit en hexadecimal :  f4347 sur  5  bits
# 1000264 s'écrit en hexadecimal :  f4348 sur  5  bits
# 1000265 s'écrit en hexadecimal :  f4349 sur  5  bits
# 1000266 s'écrit en hexadecimal :  f434a sur  5  bits
# 1000267 s'écrit en hexadecimal :  f434b sur  5  bits
# 1000268 s'écrit en hexadecimal :  f434c sur  5  bits
# 1000269 s'écrit en hexadecimal :  f434d sur  5  bits
# 1000270 s'écrit en hexadecimal :  f434e sur  5  bits
# 1000271 s'écrit en hexadecimal :  f434f sur  5  bits
# 1000272 s'écrit en hexadecimal :  f4350 sur  5  bits
# 1000273 s'écrit en hexadecimal :  f4351 sur  5  bits
# 1000274 s'écrit en hexadecimal :  f4352 sur  5  bits
# 1000275 s'écrit en hexadecimal :  f4353 sur  5  bits
# 1000276 s'écrit en hexadecimal :  f4354 sur  5  bits
# 1000277 s'écrit en hexadecimal :  f4355 sur  5  bits
# 1000278 s'écrit en hexadecimal :  f4356 sur  5  bits
# 1000279 s'écrit en hexadecimal :  f4357 sur  5  bits
# 1000280 s'écrit en hexadecimal :  f4358 sur  5  bits
# 1000281 s'écrit en hexadecimal :  f4359 sur  5  bits
# 1000282 s'écrit en hexadecimal :  f435a sur  5  bits
# 1000283 s'écrit en hexadecimal :  f435b sur  5  bits
# 1000284 s'écrit en hexadecimal :  f435c sur  5  bits
# 1000285 s'écrit en hexadecimal :  f435d sur  5  bits
# 1000286 s'écrit en hexadecimal :  f435e sur  5  bits
# 1000287 s'écrit en hexadecimal :  f435f sur  5  bits
# 1000288 s'écrit en hexadecimal :  f4360 sur  5  bits
# 1000289 s'écrit en hexadecimal :  f4361 sur  5  bits
# 1000290 s'écrit en hexadecimal :  f4362 sur  5  bits
# 1000291 s'écrit en hexadecimal :  f4363 sur  5  bits
# 1000292 s'écrit en hexadecimal :  f4364 sur  5  bits
# 1000293 s'écrit en hexadecimal :  f4365 sur  5  bits
# 1000294 s'écrit en hexadecimal :  f4366 sur  5  bits
# 1000295 s'écrit en hexadecimal :  f4367 sur  5  bits
# 1000296 s'écrit en hexadecimal :  f4368 sur  5  bits
# 1000297 s'écrit en hexadecimal :  f4369 sur  5  bits
# 1000298 s'écrit en hexadecimal :  f436a sur  5  bits
# 1000299 s'écrit en hexadecimal :  f436b sur  5  bits

# %% [markdown]
# ## Etape 6 :
# Reprenez votre programme et modifier la phrase de synthèse pour afficher côte à côté le binaire et le nouveau codage
#
# _exemple :_  <b>15 s'écrit en binaire  1111 et en XXXX s'écrit xxxx ? </b>

# %%
#Etape 6 : 
for a in range(0 ,300 ):
    #convertir a en binaire et l'affecter à une nouvelle variable
    ahex = hex(a)
    abin = bin(a)
    #Ecrire la phrase de synthese  
    #print (a, "s'écrit en hexadecimal : ", ahex[2:], "et en binaire ", abin[2:])
    print(f"{a} s'écrit en hexadecimal {ahex[2:]} et en binaire {abin[2:]}.")
# Out:
# 0 s'écrit en hexadecimal 0 et en binaire 0.
# 1 s'écrit en hexadecimal 1 et en binaire 1.
# 2 s'écrit en hexadecimal 2 et en binaire 10.
# 3 s'écrit en hexadecimal 3 et en binaire 11.
# 4 s'écrit en hexadecimal 4 et en binaire 100.
# 5 s'écrit en hexadecimal 5 et en binaire 101.
# 6 s'écrit en hexadecimal 6 et en binaire 110.
# 7 s'écrit en hexadecimal 7 et en binaire 111.
# 8 s'écrit en hexadecimal 8 et en binaire 1000.
# 9 s'écrit en hexadecimal 9 et en binaire 1001.
# 10 s'écrit en hexadecimal a et en binaire 1010.
# 11 s'écrit en hexadecimal b et en binaire 1011.
# 12 s'écrit en hexadecimal c et en binaire 1100.
# 13 s'écrit en hexadecimal d et en binaire 1101.
# 14 s'écrit en hexadecimal e et en binaire 1110.
# 15 s'écrit en hexadecimal f et en binaire 1111.
# 16 s'écrit en hexadecimal 10 et en binaire 10000.
# 17 s'écrit en hexadecimal 11 et en binaire 10001.
# 18 s'écrit en hexadecimal 12 et en binaire 10010.
# 19 s'écrit en hexadecimal 13 et en binaire 10011.
# 20 s'écrit en hexadecimal 14 et en binaire 10100.
# 21 s'écrit en hexadecimal 15 et en binaire 10101.
# 22 s'écrit en hexadecimal 16 et en binaire 10110.
# 23 s'écrit en hexadecimal 17 et en binaire 10111.
# 24 s'écrit en hexadecimal 18 et en binaire 11000.
# 25 s'écrit en hexadecimal 19 et en binaire 11001.
# 26 s'écrit en hexadecimal 1a et en binaire 11010.
# 27 s'écrit en hexadecimal 1b et en binaire 11011.
# 28 s'écrit en hexadecimal 1c et en binaire 11100.
# 29 s'écrit en hexadecimal 1d et en binaire 11101.
# 30 s'écrit en hexadecimal 1e et en binaire 11110.
# 31 s'écrit en hexadecimal 1f et en binaire 11111.
# 32 s'écrit en hexadecimal 20 et en binaire 100000.
# 33 s'écrit en hexadecimal 21 et en binaire 100001.
# 34 s'écrit en hexadecimal 22 et en binaire 100010.
# 35 s'écrit en hexadecimal 23 et en binaire 100011.
# 36 s'écrit en hexadecimal 24 et en binaire 100100.
# 37 s'écrit en hexadecimal 25 et en binaire 100101.
# 38 s'écrit en hexadecimal 26 et en binaire 100110.
# 39 s'écrit en hexadecimal 27 et en binaire 100111.
# 40 s'écrit en hexadecimal 28 et en binaire 101000.
# 41 s'écrit en hexadecimal 29 et en binaire 101001.
# 42 s'écrit en hexadecimal 2a et en binaire 101010.
# 43 s'écrit en hexadecimal 2b et en binaire 101011.
# 44 s'écrit en hexadecimal 2c et en binaire 101100.
# 45 s'écrit en hexadecimal 2d et en binaire 101101.
# 46 s'écrit en hexadecimal 2e et en binaire 101110.
# 47 s'écrit en hexadecimal 2f et en binaire 101111.
# 48 s'écrit en hexadecimal 30 et en binaire 110000.
# 49 s'écrit en hexadecimal 31 et en binaire 110001.
# 50 s'écrit en hexadecimal 32 et en binaire 110010.
# 51 s'écrit en hexadecimal 33 et en binaire 110011.
# 52 s'écrit en hexadecimal 34 et en binaire 110100.
# 53 s'écrit en hexadecimal 35 et en binaire 110101.
# 54 s'écrit en hexadecimal 36 et en binaire 110110.
# 55 s'écrit en hexadecimal 37 et en binaire 110111.
# 56 s'écrit en hexadecimal 38 et en binaire 111000.
# 57 s'écrit en hexadecimal 39 et en binaire 111001.
# 58 s'écrit en hexadecimal 3a et en binaire 111010.
# 59 s'écrit en hexadecimal 3b et en binaire 111011.
# 60 s'écrit en hexadecimal 3c et en binaire 111100.
# 61 s'écrit en hexadecimal 3d et en binaire 111101.
# 62 s'écrit en hexadecimal 3e et en binaire 111110.
# 63 s'écrit en hexadecimal 3f et en binaire 111111.
# 64 s'écrit en hexadecimal 40 et en binaire 1000000.
# 65 s'écrit en hexadecimal 41 et en binaire 1000001.
# 66 s'écrit en hexadecimal 42 et en binaire 1000010.
# 67 s'écrit en hexadecimal 43 et en binaire 1000011.
# 68 s'écrit en hexadecimal 44 et en binaire 1000100.
# 69 s'écrit en hexadecimal 45 et en binaire 1000101.
# 70 s'écrit en hexadecimal 46 et en binaire 1000110.
# 71 s'écrit en hexadecimal 47 et en binaire 1000111.
# 72 s'écrit en hexadecimal 48 et en binaire 1001000.
# 73 s'écrit en hexadecimal 49 et en binaire 1001001.
# 74 s'écrit en hexadecimal 4a et en binaire 1001010.
# 75 s'écrit en hexadecimal 4b et en binaire 1001011.
# 76 s'écrit en hexadecimal 4c et en binaire 1001100.
# 77 s'écrit en hexadecimal 4d et en binaire 1001101.
# 78 s'écrit en hexadecimal 4e et en binaire 1001110.
# 79 s'écrit en hexadecimal 4f et en binaire 1001111.
# 80 s'écrit en hexadecimal 50 et en binaire 1010000.
# 81 s'écrit en hexadecimal 51 et en binaire 1010001.
# 82 s'écrit en hexadecimal 52 et en binaire 1010010.
# 83 s'écrit en hexadecimal 53 et en binaire 1010011.
# 84 s'écrit en hexadecimal 54 et en binaire 1010100.
# 85 s'écrit en hexadecimal 55 et en binaire 1010101.
# 86 s'écrit en hexadecimal 56 et en binaire 1010110.
# 87 s'écrit en hexadecimal 57 et en binaire 1010111.
# 88 s'écrit en hexadecimal 58 et en binaire 1011000.
# 89 s'écrit en hexadecimal 59 et en binaire 1011001.
# 90 s'écrit en hexadecimal 5a et en binaire 1011010.
# 91 s'écrit en hexadecimal 5b et en binaire 1011011.
# 92 s'écrit en hexadecimal 5c et en binaire 1011100.
# 93 s'écrit en hexadecimal 5d et en binaire 1011101.
# 94 s'écrit en hexadecimal 5e et en binaire 1011110.
# 95 s'écrit en hexadecimal 5f et en binaire 1011111.
# 96 s'écrit en hexadecimal 60 et en binaire 1100000.
# 97 s'écrit en hexadecimal 61 et en binaire 1100001.
# 98 s'écrit en hexadecimal 62 et en binaire 1100010.
# 99 s'écrit en hexadecimal 63 et en binaire 1100011.
# 100 s'écrit en hexadecimal 64 et en binaire 1100100.
# 101 s'écrit en hexadecimal 65 et en binaire 1100101.
# 102 s'écrit en hexadecimal 66 et en binaire 1100110.
# 103 s'écrit en hexadecimal 67 et en binaire 1100111.
# 104 s'écrit en hexadecimal 68 et en binaire 1101000.
# 105 s'écrit en hexadecimal 69 et en binaire 1101001.
# 106 s'écrit en hexadecimal 6a et en binaire 1101010.
# 107 s'écrit en hexadecimal 6b et en binaire 1101011.
# 108 s'écrit en hexadecimal 6c et en binaire 1101100.
# 109 s'écrit en hexadecimal 6d et en binaire 1101101.
# 110 s'écrit en hexadecimal 6e et en binaire 1101110.
# 111 s'écrit en hexadecimal 6f et en binaire 1101111.
# 112 s'écrit en hexadecimal 70 et en binaire 1110000.
# 113 s'écrit en hexadecimal 71 et en binaire 1110001.
# 114 s'écrit en hexadecimal 72 et en binaire 1110010.
# 115 s'écrit en hexadecimal 73 et en binaire 1110011.
# 116 s'écrit en hexadecimal 74 et en binaire 1110100.
# 117 s'écrit en hexadecimal 75 et en binaire 1110101.
# 118 s'écrit en hexadecimal 76 et en binaire 1110110.
# 119 s'écrit en hexadecimal 77 et en binaire 1110111.
# 120 s'écrit en hexadecimal 78 et en binaire 1111000.
# 121 s'écrit en hexadecimal 79 et en binaire 1111001.
# 122 s'écrit en hexadecimal 7a et en binaire 1111010.
# 123 s'écrit en hexadecimal 7b et en binaire 1111011.
# 124 s'écrit en hexadecimal 7c et en binaire 1111100.
# 125 s'écrit en hexadecimal 7d et en binaire 1111101.
# 126 s'écrit en hexadecimal 7e et en binaire 1111110.
# 127 s'écrit en hexadecimal 7f et en binaire 1111111.
# 128 s'écrit en hexadecimal 80 et en binaire 10000000.
# 129 s'écrit en hexadecimal 81 et en binaire 10000001.
# 130 s'écrit en hexadecimal 82 et en binaire 10000010.
# 131 s'écrit en hexadecimal 83 et en binaire 10000011.
# 132 s'écrit en hexadecimal 84 et en binaire 10000100.
# 133 s'écrit en hexadecimal 85 et en binaire 10000101.
# 134 s'écrit en hexadecimal 86 et en binaire 10000110.
# 135 s'écrit en hexadecimal 87 et en binaire 10000111.
# 136 s'écrit en hexadecimal 88 et en binaire 10001000.
# 137 s'écrit en hexadecimal 89 et en binaire 10001001.
# 138 s'écrit en hexadecimal 8a et en binaire 10001010.
# 139 s'écrit en hexadecimal 8b et en binaire 10001011.
# 140 s'écrit en hexadecimal 8c et en binaire 10001100.
# 141 s'écrit en hexadecimal 8d et en binaire 10001101.
# 142 s'écrit en hexadecimal 8e et en binaire 10001110.
# 143 s'écrit en hexadecimal 8f et en binaire 10001111.
# 144 s'écrit en hexadecimal 90 et en binaire 10010000.
# 145 s'écrit en hexadecimal 91 et en binaire 10010001.
# 146 s'écrit en hexadecimal 92 et en binaire 10010010.
# 147 s'écrit en hexadecimal 93 et en binaire 10010011.
# 148 s'écrit en hexadecimal 94 et en binaire 10010100.
# 149 s'écrit en hexadecimal 95 et en binaire 10010101.
# 150 s'écrit en hexadecimal 96 et en binaire 10010110.
# 151 s'écrit en hexadecimal 97 et en binaire 10010111.
# 152 s'écrit en hexadecimal 98 et en binaire 10011000.
# 153 s'écrit en hexadecimal 99 et en binaire 10011001.
# 154 s'écrit en hexadecimal 9a et en binaire 10011010.
# 155 s'écrit en hexadecimal 9b et en binaire 10011011.
# 156 s'écrit en hexadecimal 9c et en binaire 10011100.
# 157 s'écrit en hexadecimal 9d et en binaire 10011101.
# 158 s'écrit en hexadecimal 9e et en binaire 10011110.
# 159 s'écrit en hexadecimal 9f et en binaire 10011111.
# 160 s'écrit en hexadecimal a0 et en binaire 10100000.
# 161 s'écrit en hexadecimal a1 et en binaire 10100001.
# 162 s'écrit en hexadecimal a2 et en binaire 10100010.
# 163 s'écrit en hexadecimal a3 et en binaire 10100011.
# 164 s'écrit en hexadecimal a4 et en binaire 10100100.
# 165 s'écrit en hexadecimal a5 et en binaire 10100101.
# 166 s'écrit en hexadecimal a6 et en binaire 10100110.
# 167 s'écrit en hexadecimal a7 et en binaire 10100111.
# 168 s'écrit en hexadecimal a8 et en binaire 10101000.
# 169 s'écrit en hexadecimal a9 et en binaire 10101001.
# 170 s'écrit en hexadecimal aa et en binaire 10101010.
# 171 s'écrit en hexadecimal ab et en binaire 10101011.
# 172 s'écrit en hexadecimal ac et en binaire 10101100.
# 173 s'écrit en hexadecimal ad et en binaire 10101101.
# 174 s'écrit en hexadecimal ae et en binaire 10101110.
# 175 s'écrit en hexadecimal af et en binaire 10101111.
# 176 s'écrit en hexadecimal b0 et en binaire 10110000.
# 177 s'écrit en hexadecimal b1 et en binaire 10110001.
# 178 s'écrit en hexadecimal b2 et en binaire 10110010.
# 179 s'écrit en hexadecimal b3 et en binaire 10110011.
# 180 s'écrit en hexadecimal b4 et en binaire 10110100.
# 181 s'écrit en hexadecimal b5 et en binaire 10110101.
# 182 s'écrit en hexadecimal b6 et en binaire 10110110.
# 183 s'écrit en hexadecimal b7 et en binaire 10110111.
# 184 s'écrit en hexadecimal b8 et en binaire 10111000.
# 185 s'écrit en hexadecimal b9 et en binaire 10111001.
# 186 s'écrit en hexadecimal ba et en binaire 10111010.
# 187 s'écrit en hexadecimal bb et en binaire 10111011.
# 188 s'écrit en hexadecimal bc et en binaire 10111100.
# 189 s'écrit en hexadecimal bd et en binaire 10111101.
# 190 s'écrit en hexadecimal be et en binaire 10111110.
# 191 s'écrit en hexadecimal bf et en binaire 10111111.
# 192 s'écrit en hexadecimal c0 et en binaire 11000000.
# 193 s'écrit en hexadecimal c1 et en binaire 11000001.
# 194 s'écrit en hexadecimal c2 et en binaire 11000010.
# 195 s'écrit en hexadecimal c3 et en binaire 11000011.
# 196 s'écrit en hexadecimal c4 et en binaire 11000100.
# 197 s'écrit en hexadecimal c5 et en binaire 11000101.
# 198 s'écrit en hexadecimal c6 et en binaire 11000110.
# 199 s'écrit en hexadecimal c7 et en binaire 11000111.
# 200 s'écrit en hexadecimal c8 et en binaire 11001000.
# 201 s'écrit en hexadecimal c9 et en binaire 11001001.
# 202 s'écrit en hexadecimal ca et en binaire 11001010.
# 203 s'écrit en hexadecimal cb et en binaire 11001011.
# 204 s'écrit en hexadecimal cc et en binaire 11001100.
# 205 s'écrit en hexadecimal cd et en binaire 11001101.
# 206 s'écrit en hexadecimal ce et en binaire 11001110.
# 207 s'écrit en hexadecimal cf et en binaire 11001111.
# 208 s'écrit en hexadecimal d0 et en binaire 11010000.
# 209 s'écrit en hexadecimal d1 et en binaire 11010001.
# 210 s'écrit en hexadecimal d2 et en binaire 11010010.
# 211 s'écrit en hexadecimal d3 et en binaire 11010011.
# 212 s'écrit en hexadecimal d4 et en binaire 11010100.
# 213 s'écrit en hexadecimal d5 et en binaire 11010101.
# 214 s'écrit en hexadecimal d6 et en binaire 11010110.
# 215 s'écrit en hexadecimal d7 et en binaire 11010111.
# 216 s'écrit en hexadecimal d8 et en binaire 11011000.
# 217 s'écrit en hexadecimal d9 et en binaire 11011001.
# 218 s'écrit en hexadecimal da et en binaire 11011010.
# 219 s'écrit en hexadecimal db et en binaire 11011011.
# 220 s'écrit en hexadecimal dc et en binaire 11011100.
# 221 s'écrit en hexadecimal dd et en binaire 11011101.
# 222 s'écrit en hexadecimal de et en binaire 11011110.
# 223 s'écrit en hexadecimal df et en binaire 11011111.
# 224 s'écrit en hexadecimal e0 et en binaire 11100000.
# 225 s'écrit en hexadecimal e1 et en binaire 11100001.
# 226 s'écrit en hexadecimal e2 et en binaire 11100010.
# 227 s'écrit en hexadecimal e3 et en binaire 11100011.
# 228 s'écrit en hexadecimal e4 et en binaire 11100100.
# 229 s'écrit en hexadecimal e5 et en binaire 11100101.
# 230 s'écrit en hexadecimal e6 et en binaire 11100110.
# 231 s'écrit en hexadecimal e7 et en binaire 11100111.
# 232 s'écrit en hexadecimal e8 et en binaire 11101000.
# 233 s'écrit en hexadecimal e9 et en binaire 11101001.
# 234 s'écrit en hexadecimal ea et en binaire 11101010.
# 235 s'écrit en hexadecimal eb et en binaire 11101011.
# 236 s'écrit en hexadecimal ec et en binaire 11101100.
# 237 s'écrit en hexadecimal ed et en binaire 11101101.
# 238 s'écrit en hexadecimal ee et en binaire 11101110.
# 239 s'écrit en hexadecimal ef et en binaire 11101111.
# 240 s'écrit en hexadecimal f0 et en binaire 11110000.
# 241 s'écrit en hexadecimal f1 et en binaire 11110001.
# 242 s'écrit en hexadecimal f2 et en binaire 11110010.
# 243 s'écrit en hexadecimal f3 et en binaire 11110011.
# 244 s'écrit en hexadecimal f4 et en binaire 11110100.
# 245 s'écrit en hexadecimal f5 et en binaire 11110101.
# 246 s'écrit en hexadecimal f6 et en binaire 11110110.
# 247 s'écrit en hexadecimal f7 et en binaire 11110111.
# 248 s'écrit en hexadecimal f8 et en binaire 11111000.
# 249 s'écrit en hexadecimal f9 et en binaire 11111001.
# 250 s'écrit en hexadecimal fa et en binaire 11111010.
# 251 s'écrit en hexadecimal fb et en binaire 11111011.
# 252 s'écrit en hexadecimal fc et en binaire 11111100.
# 253 s'écrit en hexadecimal fd et en binaire 11111101.
# 254 s'écrit en hexadecimal fe et en binaire 11111110.
# 255 s'écrit en hexadecimal ff et en binaire 11111111.
# 256 s'écrit en hexadecimal 100 et en binaire 100000000.
# 257 s'écrit en hexadecimal 101 et en binaire 100000001.
# 258 s'écrit en hexadecimal 102 et en binaire 100000010.
# 259 s'écrit en hexadecimal 103 et en binaire 100000011.
# 260 s'écrit en hexadecimal 104 et en binaire 100000100.
# 261 s'écrit en hexadecimal 105 et en binaire 100000101.
# 262 s'écrit en hexadecimal 106 et en binaire 100000110.
# 263 s'écrit en hexadecimal 107 et en binaire 100000111.
# 264 s'écrit en hexadecimal 108 et en binaire 100001000.
# 265 s'écrit en hexadecimal 109 et en binaire 100001001.
# 266 s'écrit en hexadecimal 10a et en binaire 100001010.
# 267 s'écrit en hexadecimal 10b et en binaire 100001011.
# 268 s'écrit en hexadecimal 10c et en binaire 100001100.
# 269 s'écrit en hexadecimal 10d et en binaire 100001101.
# 270 s'écrit en hexadecimal 10e et en binaire 100001110.
# 271 s'écrit en hexadecimal 10f et en binaire 100001111.
# 272 s'écrit en hexadecimal 110 et en binaire 100010000.
# 273 s'écrit en hexadecimal 111 et en binaire 100010001.
# 274 s'écrit en hexadecimal 112 et en binaire 100010010.
# 275 s'écrit en hexadecimal 113 et en binaire 100010011.
# 276 s'écrit en hexadecimal 114 et en binaire 100010100.
# 277 s'écrit en hexadecimal 115 et en binaire 100010101.
# 278 s'écrit en hexadecimal 116 et en binaire 100010110.
# 279 s'écrit en hexadecimal 117 et en binaire 100010111.
# 280 s'écrit en hexadecimal 118 et en binaire 100011000.
# 281 s'écrit en hexadecimal 119 et en binaire 100011001.
# 282 s'écrit en hexadecimal 11a et en binaire 100011010.
# 283 s'écrit en hexadecimal 11b et en binaire 100011011.
# 284 s'écrit en hexadecimal 11c et en binaire 100011100.
# 285 s'écrit en hexadecimal 11d et en binaire 100011101.
# 286 s'écrit en hexadecimal 11e et en binaire 100011110.
# 287 s'écrit en hexadecimal 11f et en binaire 100011111.
# 288 s'écrit en hexadecimal 120 et en binaire 100100000.
# 289 s'écrit en hexadecimal 121 et en binaire 100100001.
# 290 s'écrit en hexadecimal 122 et en binaire 100100010.
# 291 s'écrit en hexadecimal 123 et en binaire 100100011.
# 292 s'écrit en hexadecimal 124 et en binaire 100100100.
# 293 s'écrit en hexadecimal 125 et en binaire 100100101.
# 294 s'écrit en hexadecimal 126 et en binaire 100100110.
# 295 s'écrit en hexadecimal 127 et en binaire 100100111.
# 296 s'écrit en hexadecimal 128 et en binaire 100101000.
# 297 s'écrit en hexadecimal 129 et en binaire 100101001.
# 298 s'écrit en hexadecimal 12a et en binaire 100101010.
# 299 s'écrit en hexadecimal 12b et en binaire 100101011.

# %% [markdown]
# Que remarquez vous ?
